# %% [markdown]
# # Data Analysis: Test Dataset
# *Generated by Autonomous Data Analyst Agent*
#
# **Date:** 2026-07-19 23:33

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('/private/var/folders/hs/qzvy8mk56610sg9pff64sk1r0000gp/T/pytest-of-shashwatsharma/pytest-5/test_routes_to_done0/sample_sales.csv')
print(df.shape)

# %% [markdown]
# ## Descriptive Statistics
# *Summarize numeric columns*

# %%
CHART_PATH = 'chart_task_001.png'

print(df.describe())

# %% [markdown]
# **Insight:** Sales average around 3000 with stable variance.
#
# *Confidence: 90%*
